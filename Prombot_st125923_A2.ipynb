# %% [markdown]
# # Task 1 - Implementation
# Some notes about this assignment.
# - I declare some of the type hints that basiclly tells what the data type should be. (Python does not enforce it even if I put it in)
# - Some of the code in this jupyter notebook is copied into `utils` folder which I make it as a module so it makes some part of the experiments compatible with the module naming and type hinting dependency in pickle file when saving the model. For instance, saving the model  with `mlflow` which its class initialized in jupyter notebook and loading it later with `mlflow` will cause the model class to error because the model class will be `__main__.LinearRegression` which the `__main__` is a namespace from Jupyter Notebook itself, when `mlflow` tries to use the pickled model, it will try to find module named `__main__` to import the class `LinearRegression` from which is impossible to do. So I have to copy the classes from this jupyter notebook to be in another module folder `utils` that can be imported inside a function to train and save the model. After doing this, the model module path will be `utils.model.LinearRegression`. Also I have to replicate the module folder again in backend server as well

# %% [markdown]
# ## Import dependencies and declaring some type hints

# %%
import itertools
from abc import ABC, abstractmethod
from dataclasses import dataclass
from typing import Literal

import mlflow
import numpy as np
import pandas as pd
from numpy.typing import NDArray
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import KFold, train_test_split
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, PolynomialFeatures, StandardScaler

# from utils import data_cleaning, get_preprocessor

# %%
# np.number is a base class for all integers, floating numbers in numpy
# In Python 3.12, type keyword wass introduced to replace typing.TypeAlias
# read more about this https://docs.astral.sh/ruff/rules/non-pep695-type-alias/
type Vector = NDArray[np.integer | np.floating]
type Matrix = NDArray[np.integer | np.floating]
type Scalar = int | float | np.integer | np.floating

# These are old alternatives
# Vector: TypeAlias = NDArray[np.integer | np.floating]
# Matric: TypeAlias = NDArray[np.integer | np.floating]
# Scalar: TypeAlias = int | float | np.integer | np.floating


type TrainMethod = Literal["batch", "stochastic", "mini-batch"]
type WeightInitMethod = Literal["zero", "xavier"]


@dataclass
class KFoldScore:
    train_loss: float
    val_loss: float
    val_r2: float

# %% [markdown]
# ## Connecting to MLFlow

# %%
mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment("Car Price Prediction")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/769694705593400528', creation_time=1757233222067, experiment_id='769694705593400528', last_update_time=1757233222067, lifecycle_stage='active', name='Car Price Prediction', tags={}>

# %% [markdown]
# ## Declare Penalty Classes

# %%
class BasePenalty(ABC):
    @abstractmethod
    def __call__(self, theta: Vector) -> Scalar:
        pass

    @abstractmethod
    def derivation(self, theta: Vector) -> Vector:
        pass


class LassoPenalty(BasePenalty):
    def __init__(self, l: Scalar) -> None:
        self.l = l  # lambda value

    # __call__ allows call class as method
    def __call__(self, theta: Vector) -> Scalar:
        return self.l * np.sum(np.abs(theta[1:]))  # do not regularize bias term

    def derivation(self, theta: Vector) -> Vector:
        g = np.zeros_like(theta)
        g[1:] = self.l * np.sign(theta[1:])  # do not regularize bias term
        return g


class RidgePenalty(BasePenalty):
    def __init__(self, l: Scalar) -> None:
        self.l = l

    def __call__(self, theta: Vector) -> Scalar:
        return self.l * np.sum(np.square(theta[1:]))  # do not regularize bias term

    def derivation(self, theta: Vector) -> Vector:
        g = np.zeros_like(theta)
        g[1:] = self.l * 2 * (theta[1:])  # do not regularize bias term
        return g

# %%
# This is not used in the assignment but I implemented it anyway

# class ElasticPenalty(BasePenalty):
#     def __init__(self, l: Scalar = 0.1, l_ratio: Scalar = 0.5) -> None:
#         self.l = l
#         self.l_ratio = l_ratio

#     def __call__(self, theta: Vector) -> Scalar:
#         # The coefficient 1 is to avoid double counting of lambda
#         # Also, do not regularize the bias term but this is handled in Lasso and Ridge
#         # So just pass the full theta
#         l1_contribution = self.l_ratio * LassoPenalty(1)(theta)
#         l2_contribution = (1 - self.l_ratio) * RidgePenalty(1)(theta)
#         return self.l * (l1_contribution + l2_contribution)

#     def derivation(self, theta: Vector) -> Vector:
#         # The coefficient 1 and passing full theta is here as well
#         l1_derivation = self.l_ratio * LassoPenalty(1).derivation(theta)
#         l2_derivation = (1 - self.l_ratio) * RidgePenalty(1).derivation(theta)
#         return self.l * (l1_derivation + l2_derivation)

# %% [markdown]
# ## Declare the Model Class and its variants

# %%
class LinearRegression(BaseEstimator, RegressorMixin):
    cv = KFold(n_splits=3, shuffle=True, random_state=42)

    def __init__(
        self,
        regularization: BasePenalty | None,
        momentum: float,
        train_method: TrainMethod,
        weight_init_method: WeightInitMethod,
        lr: Scalar,
        num_epochs: int,
        batch_size: int | None,
        params_for_logging: dict,
    ) -> None:
        if (train_method in {"batch", "stochastic"}) and batch_size is not None:
            print("Error: Batch size should be None for batch or stochastic gradient descent.")
            return
        if train_method == "mini-batch" and (batch_size is None or batch_size <= 0):
            print("Error: Please provide a valid batch size for mini-batch gradient descent.")
            return
        if regularization is not None and not issubclass(type(regularization), BasePenalty):
            print("Error: regularization should be a subclass of BasePenalty or None.")
            return

        self.regularization = regularization
        self.momentum = momentum
        self.train_method = train_method
        self.weight_init_method = weight_init_method
        self.lr = lr
        self.num_epochs = num_epochs
        self.batch_size = batch_size
        self.params_for_logging = params_for_logging

    def mse(self, ytrue: Vector, ypred: Vector) -> Scalar:
        return ((ypred - ytrue) ** 2).sum() / ytrue.shape[0]

    def r_squared(self, ytrue: Vector, ypred: Vector) -> Scalar:
        # Formula is 1 - SSres / SStot
        # SSres = Sum of squared residual
        # SStot = Sum of squared totsl (compared to the mean or ybar)
        return 1 - np.sum(np.square(ytrue - ypred)) / np.sum(np.square(ytrue - ytrue.mean()))

    def xavier_weight_init(self, m: int, n: int) -> Vector:
        # Since this method use number of samples to calculate a new uniform range,
        # it requires both m and n to initialize theta (n, )
        upper = 1 / np.sqrt(m)
        lower = -(upper)
        numbers = np.random.rand(n)
        # The scaled output is calculated by
        # 1. streching U(0, 1) into U(0, upper - lower)
        #    with upper - lower = length between lower and upper
        # 2. Add lower to shift all the numbers back to U(lower, upper)
        return lower + numbers * (upper - lower)

    def zero_weight_init(self, n: int) -> Vector:
        return np.zeros(n)

    def weight_init(self, X: Matrix) -> Vector:
        if self.weight_init_method == "zero":
            self.theta = np.zeros(X.shape[1])
        elif self.weight_init_method == "xavier":
            self.theta = self.xavier_weight_init(X.shape[0], X.shape[1])

    def add_intercept(self, X: Matrix) -> Matrix:
        return np.hstack([np.ones((X.shape[0], 1)), X])

    def fit(self, X_train: Matrix, y_train: Vector) -> None:
        # create a list of kfold scores
        self.kfold_scores: list[KFoldScore] = []

        # kfold.split in the sklearn.....
        for fold, (train_idx, val_idx) in enumerate(self.cv.split(X_train)):
            # reset val loss at the start of each fold, not outside the fold loop
            self.val_loss_old = np.inf
            self.val_r2_old = -np.inf

            X_cross_train = X_train[train_idx]
            y_cross_train = y_train[train_idx]
            X_cross_val = X_train[val_idx]
            y_cross_val = y_train[val_idx]

            # add intercept column to training set as well as validation set
            # so that theta[0] is the bias / intercept
            # X_cross_train has size (m, n+1)
            # X_cross_val has size (m, n+1)
            X_cross_train = self.add_intercept(X_cross_train)
            X_cross_val = self.add_intercept(X_cross_val)

            # define X_cross_train as only a subset of the data
            # how big is this subset?  => mini-batch size ==> 50

            # initialize theta for each fold
            self.weight_init(X_cross_train)
            # This should be vector of same shape as theta
            # but initialized to zero as it will broadcasted anyway
            self.prev_step = 0  # for momentum

            # one epoch will exhaust the WHOLE training set
            with mlflow.start_run(run_name=f"Fold-{fold}", nested=True):
                mlflow.log_params(self.params_for_logging)

                for epoch in range(self.num_epochs):
                    # with replacement or no replacement
                    # with replacement means just randomize
                    # with no replacement means 0:50, 51:100, 101:150, ......300:323
                    # shuffle your index
                    # https://docs.astral.sh/ruff/rules/numpy-legacy-random/
                    perm = np.random.permutation(X_cross_train.shape[0])

                    X_cross_train = X_cross_train[perm]
                    y_cross_train = y_cross_train[perm]

                    train_loss = self.start_training(X_cross_train, y_cross_train)

                    yhat_val = self.predict(X_cross_val, add_intercept=False)
                    val_loss_new = self.mse(y_cross_val, yhat_val)
                    val_r2_new = self.r_squared(y_cross_val, yhat_val)
                    mlflow.log_metrics(
                        {
                            "train_loss": train_loss,
                            "val_loss": val_loss_new,
                            "val_r2": val_r2_new,
                        },
                        step=epoch,
                    )

                    # early stopping
                    if np.allclose(val_loss_new, self.val_loss_old):
                        break
                    self.val_loss_old = val_loss_new
                    self.val_r2_old = val_r2_new

                # Log all the metrics for all folds
                self.kfold_scores.append(
                    KFoldScore(
                        train_loss=train_loss,
                        val_loss=val_loss_new,
                        val_r2=val_r2_new,
                    ),
                )
                print(f"Fold {fold} Train Loss: {train_loss}")
                print(f"Fold {fold} Val Loss:   {val_loss_new}")
                print(f"Fold {fold} Val R2:     {val_r2_new}")

    def start_training(self, X_train: Matrix, y_train: Vector) -> float:
        if self.train_method == "stochastic":
            for batch_idx in range(X_train.shape[0]):
                # (11,) ==> (1, 11) ==> (m, n)
                X_method_train = X_train[batch_idx].reshape(1, -1)
                y_method_train = y_train[batch_idx].reshape(1)  # So this has shape (1,) -> not scalar
                train_loss = self._train(X_method_train, y_method_train)
        elif self.train_method == "mini-batch":
            for batch_idx in range(0, X_train.shape[0], self.batch_size):
                # batch_idx = 0, 50, 100, 150
                X_method_train = X_train[batch_idx : batch_idx + self.batch_size, :]
                y_method_train = y_train[batch_idx : batch_idx + self.batch_size]
                train_loss = self._train(X_method_train, y_method_train)
        elif self.train_method == "batch":
            X_method_train = X_train
            y_method_train = y_train
            train_loss = self._train(X_method_train, y_method_train)
        else:
            msg = "Error: Please select correct training method."
            raise ValueError(msg)
        return train_loss

    def _train(self, X: Matrix, y: Vector) -> Scalar:
        yhat = self.predict(X, add_intercept=False)
        m = X.shape[0]
        grad_loss = (2 / m) * X.T @ (yhat - y)
        if self.regularization is not None:  # noqa: SIM108
            grad_penalty = self.regularization.derivation(self.theta) / m
        else:
            grad_penalty = 0
        grad = grad_loss + grad_penalty
        step = self.lr * grad
        # If momentum is 0, second term is 0, so no momentum
        self.theta = self.theta - step + self.momentum * self.prev_step
        self.prev_step = step

        return self.mse(y, yhat)

    # Added automatic adding intercept so that when calling the model have nicer interface to work with
    def predict(self, X: Matrix, *, add_intercept: bool = True) -> Vector:
        if add_intercept:
            X = self.add_intercept(X)
        return X @ self.theta  # ===>(m, n) @ (n, )

    def _coef(self) -> Vector:
        return self.theta[1:]  # remind that theta is (w0, w1, w2, w3, w4.....wn)
        # w0 is the bias or the intercept
        # w1....wn are the weights / coefficients / theta

    def _bias(self) -> Scalar:
        return self.theta[0]

    def get_average_kfold_scores(self) -> KFoldScore:
        # return the average of the kfold scores
        return KFoldScore(**pd.DataFrame(self.kfold_scores).mean().to_dict())

    def plot_feature_importance(self, feature_names: list[str]) -> None:
        import matplotlib.pyplot as plt

        coef = self._coef()
        if len(coef) != len(feature_names):
            print("Error: Length of feature names must match number of features.")
            return

        feature_importance = pd.Series(coef, index=feature_names).sort_values(ascending=False)

        plt.figure(figsize=(10, 6))
        feature_importance.plot(kind="barh")
        plt.title("Feature Importance")
        plt.ylabel("Coefficient Value")
        plt.xlabel("Feature")
        plt.tight_layout()
        plt.show()


class Lasso(LinearRegression):
    def __init__(
        self,
        l: Scalar,
        momentum: float,
        train_method: TrainMethod,
        weight_init_method: WeightInitMethod,
        lr: Scalar,
        num_epochs: int,
        batch_size: int | None,
        params_for_logging: dict,
    ) -> None:
        super().__init__(
            regularization=LassoPenalty(l),
            momentum=momentum,
            train_method=train_method,
            weight_init_method=weight_init_method,
            lr=lr,
            num_epochs=num_epochs,
            batch_size=batch_size,
            params_for_logging=params_for_logging,
        )


class Ridge(LinearRegression):
    def __init__(
        self,
        l: Scalar,
        momentum: float,
        train_method: TrainMethod,
        weight_init_method: WeightInitMethod,
        lr: Scalar,
        num_epochs: int,
        batch_size: int | None,
        params_for_logging: dict,
    ) -> None:
        super().__init__(
            regularization=RidgePenalty(l),
            momentum=momentum,
            train_method=train_method,
            weight_init_method=weight_init_method,
            lr=lr,
            num_epochs=num_epochs,
            batch_size=batch_size,
            params_for_logging=params_for_logging,
        )

# %%
# This is not used in the assignment but I implemented it anyway

# class ElasticNet(LinearRegression):
#     def __init__(
#         self,
#         l: Scalar,
#         l_ratio: Scalar,
#         momentum: float,
#         train_method: TrainMethod,
#         weight_init_method: WeightInitMethod,
#         lr: Scalar,
#         num_epochs: int,
#         batch_size: int | None,
#         params_for_logging: dict,
#     ) -> None:
#         super().__init__(
#             regularization=ElasticPenalty(l, l_ratio),
#             momentum=momentum,
#             train_method=train_method,
#             weight_init_method=weight_init_method,
#             lr=lr,
#             num_epochs=num_epochs,
#             batch_size=batch_size,
#             params_for_logging=params_for_logging,
#         )

# %% [markdown]
# ## Preparing the data

# %% [markdown]
# ### Data Cleaning
# - I just use the old function from Assignment 1 so the data stays the same

# %%
def data_cleaning(input_df: pd.DataFrame) -> pd.DataFrame:
    df = input_df.copy()

    # Drop unused columns first to reduce size
    df = df.drop(columns=["torque"])

    # Drop rows that will definitely not be used
    df = df[~df["fuel"].isin(["CNG", "LPG"])]
    df = df[df["owner"] != "Test Drive Car"]

    # Remove Units
    df["mileage"] = df["mileage"].str.split(" ").str[0]
    df["engine"] = df["engine"].str.split(" ").str[0]
    df["max_power"] = df["max_power"].str.split(" ").str[0]

    # Numeric Type conversion
    df["mileage"] = df["mileage"].astype(float)
    df["engine"] = df["engine"].astype(float)
    df["max_power"] = df["max_power"].astype(float)

    # Fix Brand column
    df = df.rename(columns={"name": "brand"})
    df["brand"] = df["brand"].str.split(" ").str[0]

    return df


# Load, Clean, Split, Preprocess Data
df = pd.read_csv("Cars.csv")
df_train, df_test = train_test_split(df, random_state=42, test_size=0.2)
df_train = data_cleaning(df_train)
df_test = data_cleaning(df_test)
X_train = df_train.drop(columns=["selling_price"])
X_test = df_test.drop(columns=["selling_price"])
y_train = df_train["selling_price"]
y_test = df_test["selling_price"]

# %%
X_train.shape
# Out:
# (6421, 11)

# %%
print("X_train shape:", X_train.shape, type(X_train))
print("X_test shape:", X_test.shape, type(X_test))
print("y_train shape:", y_train.shape, type(y_train))
print("y_test shape:", y_test.shape, type(y_test))
# Out:
# X_train shape: (6421, 11) <class 'pandas.core.frame.DataFrame'>
# X_test shape: (1607, 11) <class 'pandas.core.frame.DataFrame'>
# y_train shape: (6421,) <class 'pandas.core.series.Series'>
# y_test shape: (1607,) <class 'pandas.core.series.Series'>

# %% [markdown]
# ### Preprocessor
# - Preprocessor is mostly the same as Assignment 1 with some tweak for polynomial features for numerical values, I will explain in the report at the end why numerical features only.

# %%
# This function was added to utils folder for easy workflow during the assignment period
# But I paste it here so that it shows up in the file for submission


def get_preprocessor(polynomial_degree: int | None = None) -> ColumnTransformer:
    # Define transformers for each feature group
    brand_le = (
        "brand_le",
        Pipeline(
            [
                # Pre-imputer for handling missing values before encoding
                ("pre_imputer", SimpleImputer(strategy="most_frequent")),
                ("encoder", OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=np.nan)),
                ("post_imputer", SimpleImputer(strategy="most_frequent")),
                # Post-imputer for handling any NaN introduced by unknown categories during encoding
                # So the pipeline is robust to unseen categories in production data
                # This won't happen if frontend limits the choices to existing categories only
                # But it's better to be safe than sorry
            ],
        ),
        ["brand"],
    )

    fuel_le = (
        "fuel_le",
        Pipeline(
            [
                ("pre_imputer", SimpleImputer(strategy="most_frequent")),
                ("encoder", OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=np.nan)),
                ("post_imputer", SimpleImputer(strategy="most_frequent")),
            ],
        ),
        ["fuel"],
    )

    transmission_le = (
        "transmission_le",
        Pipeline(
            [
                ("pre_imputer", SimpleImputer(strategy="most_frequent")),
                ("encoder", OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=np.nan)),
                ("post_imputer", SimpleImputer(strategy="most_frequent")),
            ],
        ),
        ["transmission"],
    )

    owner_le = (
        "owner_le",
        Pipeline(
            [
                ("pre_imputer", SimpleImputer(strategy="most_frequent")),
                (
                    "encoder",
                    OrdinalEncoder(
                        categories=[
                            [
                                "First Owner",
                                "Second Owner",
                                "Third Owner",
                                "Fourth & Above Owner",
                            ],
                        ],
                        handle_unknown="use_encoded_value",
                        unknown_value=np.nan,
                    ),
                ),
                ("post_imputer", SimpleImputer(strategy="most_frequent")),
            ],
        ),
        ["owner"],
    )

    seller_type_ohe = (
        "seller_type_ohe",
        Pipeline(
            [
                ("imputer", SimpleImputer(strategy="most_frequent")),
                ("encoder", OneHotEncoder(sparse_output=False, drop="first", handle_unknown="ignore")),
            ],
        ),
        ["seller_type"],
    )

    pipeline_steps = [
        (
            "imputer",
            ColumnTransformer(
                transformers=[
                    ("year_imputer", SimpleImputer(strategy="median"), ["year"]),
                    ("km_imputer", SimpleImputer(strategy="median"), ["km_driven"]),
                    ("mileage_imputer", SimpleImputer(strategy="mean"), ["mileage"]),
                    ("engine_imputer", SimpleImputer(strategy="median"), ["engine"]),
                    ("max_power_imputer", SimpleImputer(strategy="median"), ["max_power"]),
                    ("seats_imputer", SimpleImputer(strategy="most_frequent"), ["seats"]),
                ],
                remainder="passthrough",
            ),
        ),
        ("scaler", StandardScaler()),
    ]

    # This is the added polynomial feature step
    if polynomial_degree is not None:
        pipeline_steps.insert(-1, ("poly", PolynomialFeatures(degree=polynomial_degree, include_bias=False)))

    num_scaler = (
        "num_scaler",
        Pipeline(pipeline_steps),
        ["year", "km_driven", "mileage", "engine", "max_power", "seats"],
    )

    # Combine all transformers into the ColumnTransformer
    return ColumnTransformer(
        transformers=[
            brand_le,
            fuel_le,
            transmission_le,
            owner_le,
            seller_type_ohe,
            num_scaler,
        ],
        remainder="passthrough",
        verbose_feature_names_out=True,
    )

# %% [markdown]
# ## Preparing the experiments
# - Here I use itertools the create all combination of the parameter sets and convert them into list of dictionaries, each dictionary has 5 keys associated with each parameters. The reason I use this data structure so i can loop through list of them and pass the param dict inside to populate the experiment and for logging inside each cv for easy reference as well.

# %%
model_types = ["Normal", "Ridge", "Lasso", "Polynomial"]
momentum = [0, 0.9]  # 0 means no momentum
train_methods = ["batch", "stochastic", "mini-batch"]
weight_init_methods = ["zero", "xavier"]
learning_rates = [0.01, 0.001, 0.0001]


all_combinations = list(
    itertools.product(
        model_types,
        momentum,
        train_methods,
        weight_init_methods,
        learning_rates,
    ),
)
keys = ["model_type", "momentum", "train_method", "weight_init_method", "learning_rate"]
params_combinations = [dict(zip(keys, comb, strict=False)) for comb in all_combinations]
len(params_combinations)
# Out:
# 144

# %%
def start_experiment(
    X_train_original: pd.DataFrame,
    y_train_original: pd.Series,
    params_combinations: list[dict],
    num_epochs: int = 500,
    batch_size: int = 32,
) -> None:
    for i, params in enumerate(params_combinations):
        # Populate all params with num_epochs, batch_size, and lambda (if applicable)
        params["num_epochs"] = num_epochs
        if params["train_method"] == "mini-batch":
            params["batch_size"] = batch_size
            train_method_log_string = f"{params['train_method']}_BatchSize-{params['batch_size']}"
        else:
            params["batch_size"] = None
            train_method_log_string = f"{params['train_method']}"
        if params["model_type"] in {"Ridge", "Lasso"}:
            params["lambda"] = 0.1

        log_string = (
            f"Reg-{params['model_type']}"
            f"_TrainMethod-{train_method_log_string}"
            f"_Momentum-{params['momentum']}"
            f"_WeightInit-{params['weight_init_method']}"
            f"_LR-{params['learning_rate']}"
        )
        mlflow.start_run(run_name=log_string)
        mlflow.log_params(params)

        print("=============== Experiment: ", i + 1, " / ", len(params_combinations), "===============")
        print(log_string)

        if params["model_type"] in ["Normal", "Polynomial"]:
            model = LinearRegression(
                regularization=None,
                momentum=params["momentum"],
                train_method=params["train_method"],
                weight_init_method=params["weight_init_method"],
                lr=params["learning_rate"],
                num_epochs=params["num_epochs"],
                batch_size=params["batch_size"],
                params_for_logging=params,
            )
        elif params["model_type"] == "Ridge":
            model = Ridge(
                l=params["lambda"],
                momentum=params["momentum"],
                train_method=params["train_method"],
                weight_init_method=params["weight_init_method"],
                lr=params["learning_rate"],
                num_epochs=params["num_epochs"],
                batch_size=params["batch_size"],
                params_for_logging=params,
            )
        elif params["model_type"] == "Lasso":
            model = Lasso(
                l=params["lambda"],
                momentum=params["momentum"],
                train_method=params["train_method"],
                weight_init_method=params["weight_init_method"],
                lr=params["learning_rate"],
                num_epochs=params["num_epochs"],
                batch_size=params["batch_size"],
                params_for_logging=params,
            )
        else:
            print("Error: Please select correct model type.")
            break

        # For polynomial model, add polynomial features step in the preprocessor
        if params["model_type"] == "Polynomial":
            pipeline = Pipeline(steps=[("preprocess", get_preprocessor(polynomial_degree=2))])
        else:
            pipeline = Pipeline(steps=[("preprocess", get_preprocessor())])
        pipeline.steps.append(("model", model))

        # After adding all the steps, fit the pipeline
        # The reason to fit the whole pipeline here instead of just the model
        # is to ensure that the shape of X after preprocessing will match the input of model
        # so that during prediction, I can just call pipeline.predict(X) directly
        # using the original X_train without any preprocessing
        # which will be useful during inference in production where input data is raw but human-readable
        pipeline.fit(X_train_original, y_train_original)

        # Get model from pipeline
        # (last step so index = -1)
        # and it's a tuple of (name, model) so get the model with [1]
        fitted_model: LinearRegression = pipeline.steps[-1][1]

        # After fitting the model, get average kfold scores of all folds,
        # Because each fold has its own theta after fitting, which the theta comes from
        # randomized kfold split, so I cannot just use the theta from the last fold
        # to evaluate the model performance.
        avg_kfold_scores: KFoldScore = fitted_model.get_average_kfold_scores()

        print("Average training loss (MSE): ", avg_kfold_scores.train_loss)
        print("Average validation loss (MSE): ", avg_kfold_scores.val_loss)
        print("Average validation R2: ", avg_kfold_scores.val_r2)

        mlflow.log_metric(key="avg_train_mse", value=avg_kfold_scores.train_loss)
        mlflow.log_metric(key="avg_val_mse", value=avg_kfold_scores.val_loss)
        mlflow.log_metric(key="avg_val_r2", value=avg_kfold_scores.val_r2)

        # No logging the model for now as i need to fit model again
        # based on the the best average val loss

        # Below this is the old code provided in Regularization.ipynb
        # which saves only the last fold model which is not correct
        # I will refit the model with the best params and save the model later
        # signature = mlflow.models.infer_signature(X_train_original, pipeline.predict(X_train_original))
        # mlflow.sklearn.log_model(pipeline, name="skpipeline", signature=signature)

        mlflow.end_run()

# %%
params_combinations[107]
# Out:
# {'model_type': 'Lasso',
#  'momentum': 0.9,
#  'train_method': 'mini-batch',
#  'weight_init_method': 'xavier',
#  'learning_rate': 0.0001}

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Run the experiments

# %%
mlflow.end_run()  # just in case there is some run stuck

# %%
# suppress overflow warnings for log
import warnings

with warnings.catch_warnings():
    warnings.simplefilter("ignore", RuntimeWarning)
    start_experiment(
        X_train,
        np.log(y_train.to_numpy()),
        params_combinations=params_combinations,
        num_epochs=500,
        batch_size=50,  # only used for mini-batch training, will be ignored otherwise
    )
# Out:
# =============== Experiment:  1  /  144 ===============
# Reg-Normal_TrainMethod-batch_Momentum-0_WeightInit-zero_LR-0.01
# Fold 0 Train Loss: inf
# Fold 0 Val Loss:   inf
# Fold 0 Val R2:     -inf
# 🏃 View run Fold-0 at: http://localhost:5000/#/experiments/769694705593400528/runs/b6c7ef49dc884734a69e0f4b74348e20
# 🧪 View experiment at: http://localhost:5000/#/experiments/769694705593400528
# Fold 1 Train Loss: inf
# Fold 1 Val Loss:   inf
# Fold 1 Val R2:     -inf
# 🏃 View run Fold-1 at: http://localhost:5000/#/experiments/769694705593400528/runs/c883802a3e3347dc9ad940257e696bf4
# 🧪 View experiment at: http://localhost:5000/#/experiments/769694705593400528
# Fold 2 Train Loss: inf
# Fold 2 Val Loss:   inf
# Fold 2 Val R2:     -inf
# 🏃 View run Fold-2 at: http://localhost:5000/#/experiments/769694705593400528/runs/5721ff64e7404aac913cf9a557f82093
# 🧪 View experiment at: http://localhost:5000/#/experiments/769694705593400528
# Average training loss (MSE):  inf
# ...

# %% [markdown]
# ## Convert the output from MLFlow to be normal csv
# - All the training logs are inside `mlruns` folder which I cannot let `Git` tracks them because they create a lot of git diff lines, instead I load all of them and save them into CSV file so I can push it to `GitHub` for backup just in case I somehow lost my laptop and the re-training will cost me another 2+ hours :(

# %%
runs = mlflow.search_runs(search_all_experiments=True, output_format="pandas")
runs.to_csv("mlflow_runs.csv", index=False)

# %%
runs[runs["tags.mlflow.parentRunId"].isna()]
# Out:
#                                run_id       experiment_id    status  \
# 3    d7416a70e47f43cc88f46b47c1d4a0e9  769694705593400528  FINISHED
# 7    d0e1c94b2067451e9561e5e0ddce109e  769694705593400528  FINISHED
# 11   0718dd6320fc49a4915940752ffec4a8  769694705593400528  FINISHED
# 15   c62120a95e5947afb87cd09c71ce1f33  769694705593400528  FINISHED
# 19   e8e32659147d4432b4310480005c113f  769694705593400528  FINISHED
# ..                                ...                 ...       ...
# 559  3fc02ea2897a4cd1873358642a9bf4e2  769694705593400528  FINISHED
# 563  b3ec879409e7431d88a4577fc38128a7  769694705593400528  FINISHED
# 567  017b6875ee1441f5bfb158f1afd963b7  769694705593400528  FINISHED
# 571  25bafefc63a24461bb488104d674e437  769694705593400528  FINISHED
# 575  13e082e0fa874dbc87948bb105bc8813  769694705593400528  FINISHED
#
#                                           artifact_uri  \
# 3    mlflow-artifacts:/769694705593400528/d7416a70e...
# ...

# %% [markdown]
# - Loading the mlflow runs from csv looks the same here

# %%
run_df = pd.read_csv("mlflow_runs.csv")
run_df[run_df["tags.mlflow.parentRunId"].isna()]
# Out:
#                                run_id       experiment_id    status  \
# 3    d7416a70e47f43cc88f46b47c1d4a0e9  769694705593400528  FINISHED
# 7    d0e1c94b2067451e9561e5e0ddce109e  769694705593400528  FINISHED
# 11   0718dd6320fc49a4915940752ffec4a8  769694705593400528  FINISHED
# 15   c62120a95e5947afb87cd09c71ce1f33  769694705593400528  FINISHED
# 19   e8e32659147d4432b4310480005c113f  769694705593400528  FINISHED
# ..                                ...                 ...       ...
# 559  3fc02ea2897a4cd1873358642a9bf4e2  769694705593400528  FINISHED
# 563  b3ec879409e7431d88a4577fc38128a7  769694705593400528  FINISHED
# 567  017b6875ee1441f5bfb158f1afd963b7  769694705593400528  FINISHED
# 571  25bafefc63a24461bb488104d674e437  769694705593400528  FINISHED
# 575  13e082e0fa874dbc87948bb105bc8813  769694705593400528  FINISHED
#
#                                           artifact_uri  \
# 3    mlflow-artifacts:/769694705593400528/d7416a70e...
# ...

# %% [markdown]
# ## Finding the best parameter set

# %%
# Clean up a little bit so it's easier to read
# Also filter out the child runs (the folds) so I can see only the parent runs
# which I logged the averaged metrics there

params_runs_results = run_df[run_df["tags.mlflow.parentRunId"].isna()].drop(
    columns=[
        "tags.mlflow.parentRunId",
        "metrics.train_loss",
        "metrics.val_loss",
        "metrics.val_r2",
        "tags.mlflow.source.name",
        "tags.mlflow.source.type",
        "tags.mlflow.user",
        "status",
        "experiment_id",
        "run_id",
        "artifact_uri",
    ],
)
params_runs_results.columns
# Out:
# Index(['start_time', 'end_time', 'metrics.avg_train_mse', 'metrics.avg_val_r2',
#        'metrics.avg_val_mse', 'params.train_method', 'params.momentum',
#        'params.model_type', 'params.weight_init_method', 'params.num_epochs',
#        'params.learning_rate', 'params.batch_size', 'params.lambda',
#        'tags.mlflow.runName'],
#       dtype='object')

# %%
params_runs_results
# Out:
#                            start_time                          end_time  \
# 3    2025-09-10 13:46:11.582000+00:00  2025-09-10 13:47:10.619000+00:00
# 7    2025-09-10 13:45:09.971000+00:00  2025-09-10 13:46:11.553000+00:00
# 11   2025-09-10 13:45:09.095000+00:00  2025-09-10 13:45:09.946000+00:00
# 15   2025-09-10 13:44:08.302000+00:00  2025-09-10 13:45:09.071000+00:00
# 19   2025-09-10 13:43:08.525000+00:00  2025-09-10 13:44:08.275000+00:00
# ..                                ...                               ...
# 559  2025-09-10 09:52:14.606000+00:00  2025-09-10 09:53:14.126000+00:00
# 563  2025-09-10 09:51:44.636000+00:00  2025-09-10 09:52:14.578000+00:00
# 567  2025-09-10 09:50:20.742000+00:00  2025-09-10 09:51:44.588000+00:00
# 571  2025-09-10 09:49:03.496000+00:00  2025-09-10 09:50:20.706000+00:00
# 575  2025-09-10 09:48:40.555000+00:00  2025-09-10 09:49:03.466000+00:00
#
#      metrics.avg_train_mse  metrics.avg_val_r2  metrics.avg_val_mse  \
# ...

# %% [markdown]
# ### Find the top 5 models based on avg_val_r2 and avg_val_mse

# %%
top5_r2 = params_runs_results.nlargest(5, "metrics.avg_val_r2")
top5_min_valmse = params_runs_results.nsmallest(5, "metrics.avg_val_mse")
top5_r2_df = params_runs_results.loc[top5_r2.index]
top5_min_valmse_df = params_runs_results.loc[top5_min_valmse.index]

# %%
top5_min_valmse_df[["tags.mlflow.runName", "metrics.avg_val_mse", "metrics.avg_val_r2"]]
# Out:
#                                    tags.mlflow.runName  metrics.avg_val_mse  \
# 531  Reg-Normal_TrainMethod-stochastic_Momentum-0_W...             0.096030
# 387  Reg-Ridge_TrainMethod-stochastic_Momentum-0_We...             0.101890
# 111  Reg-Polynomial_TrainMethod-stochastic_Momentum...             0.104705
# 99   Reg-Polynomial_TrainMethod-stochastic_Momentum...             0.109274
# 543  Reg-Normal_TrainMethod-stochastic_Momentum-0_W...             0.113151
#
#      metrics.avg_val_r2
# 531            0.863948
# 387            0.855629
# 111            0.851565
# 99             0.845087
# 543            0.839384

# %%
top5_r2_df[["tags.mlflow.runName", "metrics.avg_val_mse", "metrics.avg_val_r2"]]
# Out:
#                                    tags.mlflow.runName  metrics.avg_val_mse  \
# 531  Reg-Normal_TrainMethod-stochastic_Momentum-0_W...             0.096030
# 387  Reg-Ridge_TrainMethod-stochastic_Momentum-0_We...             0.101890
# 111  Reg-Polynomial_TrainMethod-stochastic_Momentum...             0.104705
# 99   Reg-Polynomial_TrainMethod-stochastic_Momentum...             0.109274
# 543  Reg-Normal_TrainMethod-stochastic_Momentum-0_W...             0.113151
#
#      metrics.avg_val_r2
# 531            0.863948
# 387            0.855629
# 111            0.851565
# 99             0.845087
# 543            0.839384

# %% [markdown]
# ### Log the best parameters
# - As top 5 model based on average validation loss (mse) and validation r2 are the same I don't have to analyze further

# %%
for p in top5_r2_df.loc[:, "tags.mlflow.runName"]:
    print(p)
# Out:
# Reg-Normal_TrainMethod-stochastic_Momentum-0_WeightInit-xavier_LR-0.0001
# Reg-Ridge_TrainMethod-stochastic_Momentum-0_WeightInit-xavier_LR-0.0001
# Reg-Polynomial_TrainMethod-stochastic_Momentum-0_WeightInit-zero_LR-0.0001
# Reg-Polynomial_TrainMethod-stochastic_Momentum-0_WeightInit-xavier_LR-0.0001
# Reg-Normal_TrainMethod-stochastic_Momentum-0_WeightInit-zero_LR-0.0001

# %% [markdown]
# ## Refit the model with entire training set and best parameter set

# %% [markdown]
# ### Declare a new class inheritted from LinearRegression
# - This doesn't have CV because there is no validation set anymore

# %%
# This will be copied to the model.py for deployment compatibility
class LinearRegressionNoCV(LinearRegression):
    def fit(self, X_train_ori: Matrix, y_train_ori: Vector) -> None:
        X_train = X_train_ori.copy()
        y_train = y_train_ori.copy()
        X_train = self.add_intercept(X_train)

        # initialize theta
        self.weight_init(X_train)
        self.prev_step = 0  # for momentum

        # one epoch will exhaust the WHOLE training set

        for _ in range(self.num_epochs):
            perm = np.random.permutation(X_train.shape[0])

            X_train = X_train[perm]
            y_train = y_train[perm]

            train_loss = self.start_training(X_train, y_train)

        print(f"Last Train Loss: {train_loss}")

# %% [markdown]
# ### Fit the final model

# %%
def train_final_model() -> None:
    from utils import LinearRegressionNoCV

    final_pipe = Pipeline(
        steps=[
            ("preprocess", get_preprocessor()),
            (
                "model",
                LinearRegressionNoCV(
                    regularization=None,
                    momentum=0,
                    train_method="stochastic",
                    weight_init_method="xavier",
                    lr=0.0001,
                    num_epochs=500,
                    batch_size=None,
                    params_for_logging={},  # No need to log, this is final model with chosen params
                ),
            ),
        ],
    )
    final_pipe.fit(X_train, np.log(y_train.to_numpy()))
    return final_pipe


final_pipe = train_final_model()
# Out:
# Last Train Loss: 0.03125968917514776

# %%
signature = mlflow.models.infer_signature(X_train, final_pipe.predict(X_train))
mlflow.sklearn.log_model(final_pipe, name="final_pipe", signature=signature)
# Out:
# d:\AT82.03-ML-Car-Price-Prediction\.venv\Lib\site-packages\sklearn\pipeline.py:61: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(
# ...

# %% [markdown]
# ## Comparing the final model with sklearn Linear Regresion

# %%
loaded_model = mlflow.sklearn.load_model(
    model_uri="mlartifacts/769694705593400528/models/m-21e8645ce11644e696c9fd5b24a762fd/artifacts",
)

# %%
y_pred = loaded_model.predict(X_test)
# Out:
# d:\AT82.03-ML-Car-Price-Prediction\.venv\Lib\site-packages\sklearn\pipeline.py:61: FutureWarning: This Pipeline instance is not fitted yet. Call 'fit' with appropriate arguments before using other methods such as transform, predict, etc. This will raise an error in 1.8 instead of the current warning.
#   warnings.warn(

# %%
from sklearn.linear_model import LinearRegression as SklearnLinearRegression

sklearn_model = SklearnLinearRegression()
sklearn_pipe = Pipeline(steps=[("preprocess", get_preprocessor()), ("model", sklearn_model)])
sklearn_pipe.fit(X_train, np.log(y_train.to_numpy()))
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('brand_le',
#                                                   Pipeline(steps=[('pre_imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=nan)),
#                                                                   ('post_imputer',
#                                                                    SimpleImputer(strategy='most_frequent'))]),
#                                                   ['brand']),
#                                                  ('fuel_le',
# ...

# %%
y_pred_sklearn = sklearn_pipe.predict(X_test)

# %%
import pandas as pd

mse_func = loaded_model.steps[-1][1].mse
r_squared_func = loaded_model.steps[-1][1].r_squared

results = {
    "MSE": [
        mse_func(np.log(y_test.to_numpy()), y_pred),
        mse_func(np.log(y_test.to_numpy()), y_pred_sklearn),
        mse_func(y_test.to_numpy(), np.exp(y_pred)),
        mse_func(y_test.to_numpy(), np.exp(y_pred_sklearn)),
    ],
    "R2": [
        r_squared_func(np.log(y_test.to_numpy()), y_pred),
        r_squared_func(np.log(y_test.to_numpy()), y_pred_sklearn),
        r_squared_func(y_test.to_numpy(), np.exp(y_pred)),
        r_squared_func(y_test.to_numpy(), np.exp(y_pred_sklearn)),
    ],
}

results_df = pd.DataFrame(
    results,
    index=[
        "MyModel (log scale)",
        "Sklearn (log scale)",
        "MyModel (original scale)",
        "Sklearn (original scale)",
    ],
)
results_df["MSE"] = results_df["MSE"].apply(lambda x: f"{x:.4f}")
results_df["R2"] = results_df["R2"].apply(lambda x: f"{x:.4f}")

results_df.T

# This shows that my model is very close to sklearn's
# Out:
#     MyModel (log scale) Sklearn (log scale) MyModel (original scale)  \
# MSE              0.0919              0.0918         88113639914.7079
# R2               0.8657              0.8657                   0.8623
#
#     Sklearn (original scale)
# MSE         88821891150.2106
# R2                    0.8612

# %%
loaded_model.steps[-1][1].plot_feature_importance(
    feature_names=loaded_model.steps[0][1].get_feature_names_out().tolist(),
)

# %%
# Get categories for transmission and fuel from the fitted OrdinalEncoder
print(loaded_model.named_steps["preprocess"].named_transformers_["transmission_le"].named_steps["encoder"].categories_)
print(loaded_model.named_steps["preprocess"].named_transformers_["fuel_le"].named_steps["encoder"].categories_)
print(loaded_model.named_steps["preprocess"].named_transformers_["owner_le"].named_steps["encoder"].categories_)
# Transmission: Automatic = 0, Manual = 1
# Fuel: Diesel = 0, Petrol = 1
# Owner: First Owner = 0, Second Owner = 1, Third Owner = 2, Fourth & Above Owner = 3
# Out:
# [array(['Automatic', 'Manual'], dtype=object)]
# [array(['Diesel', 'Petrol'], dtype=object)]
# [array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner'], dtype=object)]

# %% [markdown]
# ## Looking through the results

# %% [markdown]
# ### Clean the mlruns dataframe

# %%
run_df.shape
# Out:
# (576, 25)

# %%
# This is dataframe of all runs including child runs (the folds)
run_df.head(5)
# Out:
#                              run_id       experiment_id    status  \
# 0  1ad85eaa459048d68b07875036290022  769694705593400528  FINISHED
# 1  b43dc3b4c63f4cd1ac974a973c39363e  769694705593400528  FINISHED
# 2  970232f6316e42058b34e6e8cc53b372  769694705593400528  FINISHED
# 3  d7416a70e47f43cc88f46b47c1d4a0e9  769694705593400528  FINISHED
# 4  273614647c184160ae1ff089749e3d6c  769694705593400528  FINISHED
#
#                                         artifact_uri  \
# 0  mlflow-artifacts:/769694705593400528/1ad85eaa4...
# 1  mlflow-artifacts:/769694705593400528/b43dc3b4c...
# 2  mlflow-artifacts:/769694705593400528/970232f63...
# 3  mlflow-artifacts:/769694705593400528/d7416a70e...
# 4  mlflow-artifacts:/769694705593400528/273614647...
#
#                          start_time                          end_time  \
# 0  2025-09-10 13:46:50.534000+00:00  2025-09-10 13:47:10.501000+00:00
# 1  2025-09-10 13:46:31.540000+00:00  2025-09-10 13:46:50.508000+00:00
# ...

# %%
run_df_filtered = run_df.drop(
    columns=[
        "tags.mlflow.source.name",
        "tags.mlflow.source.type",
        "tags.mlflow.user",
        "status",
        "experiment_id",
        "artifact_uri",
    ],
)
run_df_filtered.head(5)
# Out:
#                              run_id                        start_time  \
# 0  1ad85eaa459048d68b07875036290022  2025-09-10 13:46:50.534000+00:00
# 1  b43dc3b4c63f4cd1ac974a973c39363e  2025-09-10 13:46:31.540000+00:00
# 2  970232f6316e42058b34e6e8cc53b372  2025-09-10 13:46:11.677000+00:00
# 3  d7416a70e47f43cc88f46b47c1d4a0e9  2025-09-10 13:46:11.582000+00:00
# 4  273614647c184160ae1ff089749e3d6c  2025-09-10 13:45:50.331000+00:00
#
#                            end_time  metrics.train_loss  metrics.val_loss  \
# 0  2025-09-10 13:47:10.501000+00:00           11.719401         13.077980
# 1  2025-09-10 13:46:50.508000+00:00           10.831029         12.169875
# 2  2025-09-10 13:46:31.515000+00:00           11.439570         12.968844
# 3  2025-09-10 13:47:10.619000+00:00                 NaN               NaN
# 4  2025-09-10 13:46:11.430000+00:00            1.315273          2.483097
#
#    metrics.val_r2  metrics.avg_train_mse  metrics.avg_val_r2  \
# ...

# %%
# Separate parent and child runs for easier viewing
parent_runs = run_df_filtered[run_df_filtered["tags.mlflow.parentRunId"].isna()].drop(
    columns=["tags.mlflow.parentRunId", "metrics.train_loss", "metrics.val_loss", "metrics.val_r2"],
)
child_runs = run_df_filtered[~run_df_filtered["tags.mlflow.parentRunId"].isna()].drop(
    columns=["metrics.avg_train_mse", "metrics.avg_val_mse", "metrics.avg_val_r2"],
)

# %%
parent_runs.head(5)
# Out:
#                               run_id                        start_time  \
# 3   d7416a70e47f43cc88f46b47c1d4a0e9  2025-09-10 13:46:11.582000+00:00
# 7   d0e1c94b2067451e9561e5e0ddce109e  2025-09-10 13:45:09.971000+00:00
# 11  0718dd6320fc49a4915940752ffec4a8  2025-09-10 13:45:09.095000+00:00
# 15  c62120a95e5947afb87cd09c71ce1f33  2025-09-10 13:44:08.302000+00:00
# 19  e8e32659147d4432b4310480005c113f  2025-09-10 13:43:08.525000+00:00
#
#                             end_time  metrics.avg_train_mse  \
# 3   2025-09-10 13:47:10.619000+00:00              11.330000
# 7   2025-09-10 13:46:11.553000+00:00               2.380396
# 11  2025-09-10 13:45:09.946000+00:00                    inf
# 15  2025-09-10 13:45:09.071000+00:00              16.331883
# 19  2025-09-10 13:44:08.275000+00:00               2.804363
#
#     metrics.avg_val_r2  metrics.avg_val_mse params.train_method  \
# 3           -17.034224            12.738900          mini-batch
# ...

# %%
child_runs.head(5)
# Out:
#                              run_id                        start_time  \
# 0  1ad85eaa459048d68b07875036290022  2025-09-10 13:46:50.534000+00:00
# 1  b43dc3b4c63f4cd1ac974a973c39363e  2025-09-10 13:46:31.540000+00:00
# 2  970232f6316e42058b34e6e8cc53b372  2025-09-10 13:46:11.677000+00:00
# 4  273614647c184160ae1ff089749e3d6c  2025-09-10 13:45:50.331000+00:00
# 5  cdaacd5bccfe4126b9021f26ca180e2b  2025-09-10 13:45:30.313000+00:00
#
#                            end_time  metrics.train_loss  metrics.val_loss  \
# 0  2025-09-10 13:47:10.501000+00:00           11.719401         13.077980
# 1  2025-09-10 13:46:50.508000+00:00           10.831029         12.169875
# 2  2025-09-10 13:46:31.515000+00:00           11.439570         12.968844
# 4  2025-09-10 13:46:11.430000+00:00            1.315273          2.483097
# 5  2025-09-10 13:45:50.304000+00:00            2.327555          2.890049
#
#    metrics.val_r2 params.train_method  params.momentum params.model_type  \
# ...

# %% [markdown]
# ### Checking Exploding Gradients
# - Exploding gradient can be checked from folds with infinity and nan

# %%
# Learning rate 0.01 caused overflow in a lot of runs due to exploding gradients from large step size
print(np.isinf(child_runs[child_runs["params.learning_rate"] == 0.01]["metrics.val_loss"]).sum())
print(np.isinf(child_runs[child_runs["params.learning_rate"] == 0.001]["metrics.val_loss"]).sum())
print(np.isinf(child_runs[child_runs["params.learning_rate"] == 0.0001]["metrics.val_loss"]).sum())
# Out:
# 96
# 4
# 0

# %%
print(np.isnan(child_runs[child_runs["params.learning_rate"] == 0.01]["metrics.val_loss"]).sum())
print(np.isnan(child_runs[child_runs["params.learning_rate"] == 0.001]["metrics.val_loss"]).sum())
print(np.isnan(child_runs[child_runs["params.learning_rate"] == 0.0001]["metrics.val_loss"]).sum())
# Out:
# 48
# 0
# 0

# %%
print(np.isinf(child_runs[child_runs["params.train_method"] == "batch"]["metrics.val_loss"]).sum())
print(np.isinf(child_runs[child_runs["params.train_method"] == "mini-batch"]["metrics.val_loss"]).sum())
print(np.isinf(child_runs[child_runs["params.train_method"] == "stochastic"]["metrics.val_loss"]).sum())
# Out:
# 48
# 48
# 4

# %%
print(np.isnan(child_runs[child_runs["params.train_method"] == "batch"]["metrics.val_loss"]).sum())
print(np.isnan(child_runs[child_runs["params.train_method"] == "mini-batch"]["metrics.val_loss"]).sum())
print(np.isnan(child_runs[child_runs["params.train_method"] == "stochastic"]["metrics.val_loss"]).sum())
# This is interesting that stochastic has a lot of np.nan instead of inf which I will explain in summary section
# Out:
# 0
# 0
# 48

# %% [markdown]
# ## Checking the average performance by features
# - I have to filter out the infinity values so the result is calculable so the results will be just some samples of results that don't have extreme values, that means the result in this section might not represent entire experiments but they should still give similar trends and some ideas about the parameters

# %%
parent_runs[["params.learning_rate", "metrics.avg_val_mse", "metrics.avg_val_r2"]].replace(
    [np.inf, -np.inf],
    np.nan,
).dropna().groupby("params.learning_rate").mean()
# Out:
#                       metrics.avg_val_mse  metrics.avg_val_r2
# params.learning_rate
# 0.0001                          10.673834          -14.108025
# 0.0010                           6.618113           -8.367404

# %%
parent_runs[["params.model_type", "metrics.avg_val_mse", "metrics.avg_val_r2"]].replace(
    [np.inf, -np.inf],
    np.nan,
).dropna().groupby("params.model_type").mean()
# Out:
#                    metrics.avg_val_mse  metrics.avg_val_r2
# params.model_type
# Lasso                         8.568102          -11.128174
# Normal                        8.577094          -11.139239
# Polynomial                    9.160368          -11.965349
# Ridge                         8.490184          -11.017926

# %%
parent_runs[["params.train_method", "metrics.avg_val_mse", "metrics.avg_val_r2"]].replace(
    [np.inf, -np.inf],
    np.nan,
).dropna().groupby("params.train_method").mean()
# Out:
#                      metrics.avg_val_mse  metrics.avg_val_r2
# params.train_method
# batch                          20.526496          -28.055099
# mini-batch                      4.735236           -5.701469
# stochastic                      0.280060            0.604145

# %%
parent_runs[["params.weight_init_method", "metrics.avg_val_mse", "metrics.avg_val_r2"]].replace(
    [np.inf, -np.inf],
    np.nan,
).dropna().groupby("params.weight_init_method").mean()
# Out:
#                            metrics.avg_val_mse  metrics.avg_val_r2
# params.weight_init_method
# xavier                                8.716029          -11.336868
# zero                                  8.662210          -11.260702

# %%
parent_runs[["params.momentum", "metrics.avg_val_mse", "metrics.avg_val_r2"]].replace(
    [np.inf, -np.inf],
    np.nan,
).dropna().groupby("params.momentum").mean()
# Out:
#                  metrics.avg_val_mse  metrics.avg_val_r2
# params.momentum
# 0.0                         6.576299           -8.308769
# 0.9                        10.713906          -14.164217

# %% [markdown]
# ## Summary

# %% [markdown]
# ### About Parameters
# - Learning rate 0.01 is too high and cause most of the models' gradients to explode into infinity.
# - Penalty does make the model better overall (a little bit lower MSE)
# - Polynomial features reduce the model performance, probably due to too many features was included.
# - Xavier weight initialization doesn't help much
# - Batch Gradient Descent takes too long to converge, 500 epochs is not enough, resulting in high loss.
# - Batch Gradient Descent can stuck in local minima, as this image shows MSE around 20 but the model looks converged (the image below is from
# Reg-Normal_TrainMethod-batch_Momentum-0_WeightInit-zero_LR-0.0001)
# ![image.png](assets/bgd.png)
# - Mini-batch Gradient Descent makes model training a little bit more shaky for training loss but converge a lot faster than batch gradient descent. (the image below is from
# Reg-Normal_TrainMethod-mini-batch_BatchSize-50_Momentum-0_WeightInit-zero_LR-0.0001)
# ![image-3.png](assets/mbgd.png)
# - Stochastic Dradient Descent makes model training super shaky, this cause a lot of models' gradients to go into infinity. But with lowest learning rate 0.0001, it can be powerful as it can push model to converge into the lowest MSE (the image below is from
# Reg-Normal_TrainMethod-stochastic_Momentum-0_WeightInit-zero_LR-0.0001)
# ![image-4.png](assets/sgd.png)
# - Momentum somehow make the model converge slower, probably due to the momentum implemented is the most basic form of momentum (the image below is from
# Reg-Normal_TrainMethod-batch_Momentum-0.9_WeightInit-zero_LR-0.0001)
# ![image-2.png](assets/momentum.png)

# %% [markdown]
# ### About Feature Importance
# `year`, `max_power`, `engine` have high positive coefficients, which means if these features increase, the price increases. Next, `transmission (Manual)`, `fuel (Petrol)`, higher number of `owner` have negative coefficients, meaning if these features increase, the price decreases, which aligns with Pearson correlation in Assignment 1. For `brand`, even though some brands are expensive, it got almost zero coefficient, meaning that the model is ignoring it due to the large range of possible categorical values.

# %% [markdown]
# ### MLFlow Screenshot
# ![image.png](assets/mlflow.png)

# %%
top20 = params_runs_results.nsmallest(20, "metrics.avg_val_mse")
top20["tags.mlflow.runName"] = top20["tags.mlflow.runName"].str.replace("Reg-", "", regex=False)
top20["tags.mlflow.runName"] = top20["tags.mlflow.runName"].str.replace("TrainMethod-", "", regex=False)
top20["tags.mlflow.runName"] = top20["tags.mlflow.runName"].str.replace("WeightInit-", "", regex=False)
# All model use 50 for mini-batch size so remove that part to make it shorter
top20["tags.mlflow.runName"] = top20["tags.mlflow.runName"].str.replace("BatchSize-50_", "", regex=False)
top20["tags.mlflow.runName"] = top20["tags.mlflow.runName"].str.replace("LR-", "", regex=False)
top20[["tags.mlflow.runName", "metrics.avg_val_mse", "metrics.avg_val_r2"]]
# Out:
#                                 tags.mlflow.runName  metrics.avg_val_mse  \
# 531      Normal_stochastic_Momentum-0_xavier_0.0001             0.096030
# 387       Ridge_stochastic_Momentum-0_xavier_0.0001             0.101890
# 111    Polynomial_stochastic_Momentum-0_zero_0.0001             0.104705
# 99   Polynomial_stochastic_Momentum-0_xavier_0.0001             0.109274
# 543        Normal_stochastic_Momentum-0_zero_0.0001             0.113151
# 319      Ridge_stochastic_Momentum-0.9_xavier_0.001             0.113451
# 243       Lasso_stochastic_Momentum-0_xavier_0.0001             0.114229
# 255         Lasso_stochastic_Momentum-0_zero_0.0001             0.116633
# 475       Normal_stochastic_Momentum-0.9_zero_0.001             0.116665
# 399         Ridge_stochastic_Momentum-0_zero_0.0001             0.119842
# 535       Normal_stochastic_Momentum-0_xavier_0.001             0.121623
# 379          Ridge_mini-batch_Momentum-0_zero_0.001             0.123774
# ...

# %% [markdown]
# ### Best model
# The best parameter I get is
# - Normal Linear Regression (No Penalty)
# - Stochastic training method
# - No momentum
# - Xavier weight initialization
# - Learning rate 0.0001
#
# Below is the image showing one of the cv fold trained using this parameter set.
# It started with very chaotic training loss after each epoch since this is a stochastic weight update.
# But it eventually went down pretty fast which result in validation loss soon followed.
# At around 50 epochs, validation loss and R2 converged into preferable values.
#
# ![image.png](assets/bestparam.png)

# %% [markdown]
# ### Extra
# When training with a high learning rate, infinity and nan values occured in the experiment training loops. Interestingly, the nan values are found in parameter settings that involve Stochastic training method but not Batch and Mini-batch which just have infinity or negative infinity. After some investigations, I found that if there is no early stopping and more epochs, all training methods will eventually becomes nan instead of infinity. The cause of this is when yhat becomes infinity, calculating gradient involves multiplying features X.T with (yhat - ytrue), since yhat becomes np.inf, (yhat - ytrue) also becomes np.inf, then when multiplying X.T with error term, if X.T has no zero, the result will just be np.inf or -np.inf, but if there is one zero in X.T, the result will be 0 * np.inf = np.nan, then updating theta corrupts the theta with nan, then the next training loop will cascade np.nan everywhere through X @ theta
